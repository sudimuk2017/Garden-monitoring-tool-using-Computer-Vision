#   inflating: data/cassava/cassava_217.jpg
#   inflating: data/cassava/cassava_226.jpg
#   inflating: data/cassava/cassava_222.jpg
#   inflating: data/cassava/cassava_228.jpg
#   inflating: data/cassava/cassava_241.jpg
#   inflating: data/cassava/cassava_225.jpg
#   inflating: data/cassava/cassava_232.jpg
#   inflating: data/cassava/cassava_238.jpg
#   inflating: data/cassava/cassava_227.jpg
#   inflating: data/cassava/cassava_250.jpg
#   inflating: data/cassava/cassava_214.jpg
#   inflating: data/cassava/cassava_231.jpg
#   inflating: data/cassava/cassava_251.jpg
#   inflating: data/cassava/cassava_206.jpg
#   inflating: data/cassava/cassava_223.jpg
#   inflating: data/cassava/cassava_216.jpg
#   inflating: data/cassava/cassava_237.jpg
#   inflating: data/cassava/cassava_213.jpg
#   inflating: data/cassava/cassava_195.jpg
#   inflating: data/cassava/cassava_215.jpg
#   inflating: data/cassava/cassava_197.jpg
#   inflating: data/cassava/cassava_202.jpg
#   inflating: data/cassava/cassava_219.jpg
#   inflating: data/cassava/cassava_205.jpg
#   inflating: data/cassava/cassava_220.jpg
#   inflating: data/cassava/cassava_211.jpg
#   inflating: data/cassava/cassava_194.jpg
#   inflating: data/cassava/cassava_192.jpg
#   inflating: data/cassava/cassava_224.jpg
#   inflating: data/cassava/cassava_203.jpg
#   inflating: data/cassava/cassava_212.jpg
#   inflating: data/cassava/cassava_201.jpg
#   inflating: data/cassava/cassava_221.jpg
#   inflating: data/cassava/cassava_190.jpg
#   inflating: data/cassava/cassava_218.jpg
#   inflating: data/cassava/cassava_207.jpg
#   inflating: data/cassava/cassava_182.jpg
#   inflating: data/cassava/cassava_200.jpg
#   inflating: data/cassava/cassava_210.jpg
#   inflating: data/cassava/cassava_183.jpg
#   inflating: data/cassava/cassava_186.jpg
#   inflating: data/cassava/cassava_196.jpg
#   inflating: data/cassava/cassava_185.jpg
#   inflating: data/cassava/cassava_209.jpg
#   inflating: data/cassava/cassava_208.jpg
#   inflating: data/cassava/cassava_176.jpg
#   inflating: data/cassava/cassava_191.jpg
#   inflating: data/cassava/cassava_188.jpg
#   inflating: data/cassava/cassava_193.jpg
#   inflating: data/cassava/cassava_180.jpg
#   inflating: data/cassava/cassava_184.jpg
#   inflating: data/cassava/cassava_163.jpg
#   inflating: data/cassava/cassava_166.jpg
#   inflating: data/cassava/cassava_162.jpg
#   inflating: data/cassava/cassava_204.jpg
#   inflating: data/cassava/cassava_199.jpg
#   inflating: data/cassava/cassava_178.jpg
#   inflating: data/cassava/cassava_167.jpg
#   inflating: data/cassava/cassava_173.jpg
#   inflating: data/cassava/cassava_177.jpg
#   inflating: data/cassava/cassava_172.jpg
#   inflating: data/cassava/cassava_171.jpg
#   inflating: data/cassava/cassava_187.jpg
#   inflating: data/cassava/cassava_156.jpg
#   inflating: data/cassava/cassava_164.jpg
#   inflating: data/cassava/cassava_198.jpg
#   inflating: data/cassava/cassava_169.jpg
#   inflating: data/cassava/cassava_161.jpg
#   inflating: data/cassava/cassava_157.jpg
#   inflating: data/cassava/cassava_159.jpg
#   inflating: data/cassava/cassava_165.jpg
#   inflating: data/cassava/cassava_150.jpg
#   inflating: data/cassava/cassava_144.jpg
#   inflating: data/cassava/cassava_141.jpg
#   inflating: data/cassava/cassava_149.jpg
#   inflating: data/cassava/cassava_160.jpg
#   inflating: data/cassava/cassava_153.jpg
#   inflating: data/cassava/cassava_147.jpg
#   inflating: data/cassava/cassava_132.jpg
#   inflating: data/cassava/cassava_131.jpg
#   inflating: data/cassava/cassava_174.jpg
#   inflating: data/cassava/cassava_134.jpg
#   inflating: data/cassava/cassava_145.jpg
#   inflating: data/cassava/cassava_152.jpg
#   inflating: data/cassava/cassava_138.jpg
#   inflating: data/cassava/cassava_140.jpg
#   inflating: data/cassava/cassava_127.jpg
#   inflating: data/cassava/cassava_148.jpg
#   inflating: data/cassava/cassava_135.jpg
#   inflating: data/cassava/cassava_133.jpg
#   inflating: data/cassava/cassava_168.jpg
#   inflating: data/cassava/cassava_179.jpg
#   inflating: data/cassava/cassava_126.jpg
#   inflating: data/cassava/cassava_155.jpg
#   inflating: data/cassava/cassava_139.jpg
#   inflating: data/cassava/cassava_109.jpg
#   inflating: data/cassava/cassava_123.jpg
#   inflating: data/cassava/cassava_151.jpg
#   inflating: data/cassava/cassava_154.jpg
#   inflating: data/cassava/cassava_181.jpg
#   inflating: data/cassava/cassava_175.jpg
#   inflating: data/cassava/cassava_137.jpg
#   inflating: data/cassava/cassava_189.jpg
#   inflating: data/cassava/cassava_143.jpg
#   inflating: data/cassava/cassava_158.jpg
#   inflating: data/cassava/cassava_117.jpg
#   inflating: data/cassava/cassava_115.jpg
#   inflating: data/cassava/cassava_128.jpg
#   inflating: data/cassava/cassava_122.jpg
#   inflating: data/cassava/cassava_116.jpg
#   inflating: data/cassava/cassava_107.jpg
#   inflating: data/cassava/cassava_99.jpg
#   inflating: data/cassava/cassava_98.jpg
#   inflating: data/cassava/cassava_106.jpg
#   inflating: data/cassava/cassava_108.jpg
#   inflating: data/cassava/cassava_95.jpg
#   inflating: data/cassava/cassava_136.jpg
#   inflating: data/cassava/cassava_93.jpg
#   inflating: data/cassava/cassava_102.jpg
#   inflating: data/cassava/cassava_110.jpg
#   inflating: data/cassava/cassava_114.jpg
#   inflating: data/cassava/cassava_103.jpg
#   inflating: data/grass/grass_37.jpg
#   inflating: data/cassava/cassava_170.jpg
#   inflating: data/cassava/cassava_130.jpg
#   inflating: data/cassava/cassava_146.jpg
#   inflating: data/cassava/cassava_142.jpg
#   inflating: data/cassava/cassava_118.jpg
#   inflating: data/cassava/cassava_112.jpg
#   inflating: data/cassava/cassava_121.jpg
#   inflating: data/cassava/cassava_100.jpg
#   inflating: data/cassava/cassava_129.jpg
#   inflating: data/cassava/cassava_124.jpg
#   inflating: data/cassava/cassava_97.jpg
#   inflating: data/cassava/cassava_111.jpg
#   inflating: data/cassava/cassava_120.jpg
#   inflating: data/cassava/cassava_119.jpg
#   inflating: data/cassava/cassava_31.jpg
#   inflating: data/cassava/cassava_25.jpg
#   inflating: data/cassava/cassava_42.jpg
#   inflating: data/cassava/cassava_40.jpg
#   inflating: data/cassava/cassava_27.jpg
#   inflating: data/cassava/cassava_36.jpg
#   inflating: data/cassava/cassava_34.jpg
#   inflating: data/cassava/cassava_39.jpg
#   inflating: data/cassava/cassava_21.jpg
#   inflating: data/cassava/cassava_24.jpg
#   inflating: data/cassava/cassava_26.jpg
#   inflating: data/cassava/cassava_29.jpg
#   inflating: data/cassava/cassava_41.jpg
#   inflating: data/maize/maize_29.jpg
#   inflating: data/cassava/cassava_22.jpg
#   inflating: data/cassava/cassava_59.jpg
#   inflating: data/cassava/cassava_14.jpg
#   inflating: data/cassava/cassava_8.jpg
#   inflating: data/cassava/cassava_33.jpg
#   inflating: data/cassava/cassava_37.jpg
#   inflating: data/cassava/cassava_6.jpg
#   inflating: data/cassava/cassava_32.jpg
#   inflating: data/cassava/cassava_12.jpg
#   inflating: data/cassava/cassava_9.jpg
#   inflating: data/cassava/cassava_5.jpg
#   inflating: data/cassava/cassava_35.jpg
#   inflating: data/cassava/cassava_23.jpg
#   inflating: data/cassava/cassava_10.jpg
#   inflating: data/cassava/cassava_16.jpg
#   inflating: data/cassava/cassava_20.jpg
#   inflating: data/cassava/cassava_7.jpg
#   inflating: data/cassava/cassava_2.jpg
#   inflating: data/cassava/cassava_11.jpg
#   inflating: data/cassava/cassava_1.jpg
#   inflating: data/cassava/cassava_3.jpg
#   inflating: data/cassava/cassava_13.jpg
#   inflating: data/cassava/cassava_28.jpg
#   inflating: data/cassava/cassava_53.jpg
#   inflating: data/cassava/cassava_30.jpg
#   inflating: data/cassava/cassava_4.jpg
#   inflating: data/cassava/cassava_18.jpg
#   inflating: data/cassava/cassava_17.jpg
#   inflating: data/cassava/cassava_19.jpg
#   inflating: data/cassava/cassava_15.jpg

# %% [markdown]
# # Import Libraries

# %%
import os
import shutil
import glob
import random
import cv2

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, recall_score

# %% [markdown]
# # Organize the dataset

# %%
os.makedirs("./train")
os.makedirs("./test")

# %%
cassava = len(os.listdir('./data/cassava'))
maize = len(os.listdir('./data/maize'))
sugarcane = len(os.listdir('./data/sugarcane'))
grass = len(os.listdir('./data/grass'))

# %%
print(f"{cassava} Cassava Images")
print(f"{maize} Maize Images")
print(f"{sugarcane} SugarCane Images")
print(f"{grass} Grass Images")
# Out:
# 317 Cassava Images
# 304 Maize Images
# 114 SugarCane Images
# 287 Grass Images

# %%
train_data = []
for img in glob.glob('./data/cassava/*.jpg'):
  train_data.append((img,0))

for img in glob.glob('./data/maize/*.jpg'):
  train_data.append((img, 1))

for img in glob.glob('./data/sugarcane/*.jpg'):
  train_data.append((img, 2))

for img in glob.glob('./data/grass/*.jpg'):
  train_data.append((img, 3))

# %%
train_data = pd.DataFrame(train_data, columns=['plant', 'label'],index=None)
train_data['label'].value_counts()
# Out:
# 0    317
# 1    304
# 3    287
# 2    114
# Name: label, dtype: int64

# %%
train_data.head()
# Out:
#                             plant  label
# 0  ./data/cassava/cassava_152.jpg      0
# 1  ./data/cassava/cassava_229.jpg      0
# 2  ./data/cassava/cassava_283.jpg      0
# 3  ./data/cassava/cassava_261.jpg      0
# 4   ./data/cassava/cassava_16.jpg      0

# %% [markdown]
# # Data Visualization

# %%
#Plot the data
plant_count = train_data['label'].value_counts()
plt.figure(figsize=(15,10))
plt.subplot(221)
ax = sns.barplot(x=plant_count.index, y= plant_count.values)
plt.title('Number of all crops and grass', fontsize=14)
plt.xlabel('Plant type', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(range(len(plant_count.index)), ['cassava', 'sugarcane', 'maize', 'grass']),

ax.patches[0].set_color('red')
ax.patches[1].set_color('blue')
ax.patches[2].set_color('yellow')
ax.patches[3].set_color('green')
plt.show()

# %%
cassava_samples = (train_data[train_data['label']==0]['plant'].iloc[:5]).tolist()
sugarcane_samples = (train_data[train_data['label']==1]['plant'].iloc[:5]).tolist()
maize_samples = (train_data[train_data['label']==2]['plant'].iloc[:5]).tolist()
grass_samples = (train_data[train_data['label']==3]['plant'].iloc[:5]).tolist()

# Concat the data in a single list and del the above two list
samples = cassava_samples + sugarcane_samples + maize_samples + grass_samples

# %%
print(samples)
# Out:
# ['./data/cassava/cassava_152.jpg', './data/cassava/cassava_229.jpg', './data/cassava/cassava_283.jpg', './data/cassava/cassava_261.jpg', './data/cassava/cassava_16.jpg', './data/maize/maize_197.jpg', './data/maize/maize_18.jpg', './data/maize/maize_224.jpg', './data/maize/maize_108.jpg', './data/maize/maize_23.jpg', './data/sugarcane/sugarcane_58.jpg', './data/sugarcane/sugarcane_20.jpg', './data/sugarcane/sugarcane_33.jpg', './data/sugarcane/sugarcane_13.jpg', './data/sugarcane/sugarcane_18.jpg', './data/grass/grass_104.jpg', './data/grass/grass_119.jpg', './data/grass/grass_96.jpg', './data/grass/grass_275.jpg', './data/grass/grass_239.jpg']

# %%
# Plot the data
f, ax = plt.subplots(4, 5, figsize=(30, 10))
for i in range(20):
    img = Image.open(samples[i])
    ax[i // 5, i % 5].imshow(img)
    ax[i // 5, i % 5].axis('off')
    ax[i // 5, i % 5].set_aspect('auto')
    ax[i // 5, i % 5].set_title(samples[i].split("/")[-1])  # Show the image name as the title
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Prepare the data for training

# %%
path = './data'
image_paths = []

min_size = 100
max_size = 500

for folder in os.listdir(path):
    folder_path = os.path.join(path, folder)
    if os.path.isdir(folder_path):
        files = os.listdir(folder_path)
        for file in files:
            file_path = os.path.join(folder_path, file)
            img = cv2.imread(file_path)
            height, width, _ = img.shape
            if min_size <= height <= max_size and min_size <= width <= max_size:
                image_paths.append(file_path)

plt.figure(figsize=(10, 5))

for i, image_path in enumerate(image_paths):
    img = cv2.imread(image_path)
    hist = cv2.calcHist([img], [0, 1, 2], None, [8, 8, 8], [0, 256, 0, 256, 0, 256])
    hist = cv2.normalize(hist, hist).flatten()

    plt.subplot(1, len(image_paths), i+1)  # Display the images dynamically based on the number of collected images
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
path = './data'
image_path = []
for file in os.listdir(path):
  dir = os.path.join(path, file)
  for file in os.listdir(dir):
    image_path.append(os.path.join(dir, file))

# %%
len(image_path)
# Out:
# 1022

# %%
def CalcFeatures(img, target_size):
    # Resize the image to the target size
    resized_img = cv2.resize(img, target_size)

    # Calculate color histogram
    hist = cv2.calcHist([resized_img], [0, 1, 2], None, [8, 8, 8], [0, 256, 0, 256, 0, 256])
    hist = cv2.normalize(hist, hist).flatten()

    return hist

target_size = (256, 256)  # Set the desired target size for resizing

features = []
for file in image_path:
    img = cv2.imread(file)

    if img is not None:
        img_features = CalcFeatures(img, target_size)
        if img_features is not None:
            features.append(img_features)

if features:
    features = np.vstack(features)
else:
    print("No features extracted from the images.")

# %%
features.shape
# Out:
# (1022, 512)

# %%
def kmean_bow (features, num_clusters):
  # bof_dict = []
  criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 0.1)
  flags = cv2.KMEANS_RANDOM_CENTERS
  compactness, labels, centers = cv2.kmeans(features, num_clusters, None, criteria, 10, flags)
  return centers

centers = kmean_bow(features, 100)

# %%
def bag_of_features(features, centres, num_clusters):
  vec = np.zeros((1, num_clusters))
  for i in range(features.shape[0]):
    feat = features[i]
    diff = np.tile(feat, (num_clusters, 1)) - centres
    dist = pow(((pow(diff, 2)).sum(axis = 1)), 0.5)
    idx_dist = dist.argsort()
    idx = idx_dist[0]
    vec[0][idx] += 1

  return vec

# %%
def CalcFeatures(img, target_size):
    img_resized = cv2.resize(img, target_size)
    hist = cv2.calcHist([img_resized], [0, 1, 2], None, [8, 8, 8], [0, 256, 0, 256, 0, 256])
    hist = cv2.normalize(hist, hist).flatten()
    return hist

labels = []
X = []
target_size = (256, 256)

for file in image_path:
    img = cv2.imread(file)
    img_desc = CalcFeatures(img, target_size)
    if img_desc is not None:
        img_vec = bag_of_features(img_desc, centers, 100)
        X.append(img_vec)
        labels.append(file.split('/')[2])

X = np.vstack(X)

# %%
print(labels)
X.shape, len(labels)
# Out:
# ['grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'grass', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', ...
# ((1022, 100), 1022)

# %%
labels = LabelEncoder().fit_transform(labels)
X_scaled = StandardScaler().fit_transform(X)
X_pca = PCA(n_components=10).fit_transform(X_scaled)

# %%
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_pca, labels, test_size=0.3, random_state=0, stratify=labels)

# %%
# Print the sizes of each set
print("Train set size:", len(X_train))
print("Test set size:", len(X_test))
# Out:
# Train set size: 715
# Test set size: 307

# %% [markdown]
# # Train KNN model

# %%
knn = KNeighborsClassifier(n_neighbors=5, n_jobs=-1)

# %%
#fit the model
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_jobs=-1)

# %%
#Predict on the test set
knn_pred = knn.predict(X_test)

# %%
#Classification report
pd.DataFrame(classification_report(y_test, knn_pred, output_dict=True)).T
# Out:
#               precision    recall  f1-score     support
# 0              0.766667  0.484211  0.593548   95.000000
# 1              0.474359  0.860465  0.611570   86.000000
# 2              0.521739  0.260870  0.347826   92.000000
# 3              0.244444  0.323529  0.278481   34.000000
# accuracy       0.504886  0.504886  0.504886    0.504886
# macro avg      0.501802  0.482269  0.457856  307.000000
# weighted avg   0.553548  0.504886  0.490067  307.000000

# %% [markdown]
# #Confusion Matrix

# %%
cm = confusion_matrix(y_test, knn_pred)
ConfusionMatrixDisplay(cm).plot()
